# %% [markdown]
# <a href="https://colab.research.google.com/github/Mosaraf15/Data-Visualization-ML/blob/main/03_Data_Visualization_Scatter_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Data Visualization: Scatter plot**
#
# #####**Md Mosaraf Hossain Khan**
# Chittagang, Bangladesh
#
# **Objectives:**
# - Scatter plot
# - Regression line
# - Pair plot
#
# Instructor:
# #####**Md Shahidullah Kawsar**
# Data Scientist, IDARE, Houston, TX, USA
#
#
# - https://www.youtube.com/watch?v=7fIqp39XljU&list=PLGjf1T0akmhMDDJJ0-t_dUnH929YyfClM&index=4
# - https://github.com/SKawsar/Data_Visualization_with_Python_s2

# %% [markdown]
# #### References:
# [1] Seaborn Scatterplot: https://seaborn.pydata.org/generated/seaborn.scatterplot.html
# <br>[2] Seaborn Regression Line: https://seaborn.pydata.org/generated/seaborn.regplot.html
# <br>[3] Seaborn Pairplot: https://seaborn.pydata.org/generated/seaborn.pairplot.html#seaborn.pairplot
# <br>[4]dataset source: https://www.kaggle.com/aishwaryamuthukumar/cars-dataset-audi-bmw-ford-hyundai-skoda-vw

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_context('talk')
#sns.set_context('paper')
#sns.set_context('poster')
#...................

# %% [markdown]
# #### Load the dataset

# %%
df = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/Python/02 Python Data Visualization/Data_Visualization_with_Python_s2-main/toyota.csv")

display(df.head(10))
# Out:
#    model  year  price transmission  mileage fuelType   mpg  engineSize
# 0   GT86  2016  16000       Manual    24089   Petrol  36.2         2.0
# 1   GT86  2017  15995       Manual    18615   Petrol  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  36.2         2.0
# 3   GT86  2017  18998       Manual    14736   Petrol  36.2         2.0
# 4   GT86  2017  17498       Manual    36284   Petrol  36.2         2.0
# 5   GT86  2017  15998       Manual    26919   Petrol  36.2         2.0
# 6   GT86  2017  18522       Manual    10456   Petrol  36.2         2.0
# 7   GT86  2017  18995       Manual    12340   Petrol  36.2         2.0
# 8   GT86  2020  27998       Manual      516   Petrol  33.2         2.0
# 9   GT86  2016  13990       Manual    37999   Petrol  36.2         2.0

# %%
display(df.describe())
# Out:
#               year         price        mileage          mpg   engineSize
# count  6738.000000   6738.000000    6738.000000  6738.000000  6738.000000
# mean   2016.748145  12522.391066   22857.413921    63.042223     1.471297
# std       2.204062   6345.017587   19125.464147    15.836710     0.436159
# min    1998.000000    850.000000       2.000000     2.800000     0.000000
# 25%    2016.000000   8290.000000    9446.000000    55.400000     1.000000
# 50%    2017.000000  10795.000000   18513.000000    62.800000     1.500000
# 75%    2018.000000  14995.000000   31063.750000    69.000000     1.800000
# max    2020.000000  59995.000000  174419.000000   235.000000     4.500000

# %%
display(df.shape)
# Out:
# (6738, 8)

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6738 entries, 0 to 6737
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         6738 non-null   object
#  1   year          6738 non-null   int64
#  2   price         6738 non-null   int64
#  3   transmission  6738 non-null   object
#  4   mileage       6738 non-null   int64
#  5   fuelType      6738 non-null   object
#  6   mpg           6738 non-null   float64
#  7   engineSize    6738 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 421.2+ KB
# None

# %%
# another way to check missing value
df.isna().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# mpg             0
# engineSize      0
# dtype: int64

# %%
print(len(df["model"].unique()))
# Out:
# 18

# %%
print(df["transmission"].unique())
# Out:
# ['Manual' 'Automatic' 'Semi-Auto' 'Other']

# %%
print(df["fuelType"].unique())
# Out:
# ['Petrol' 'Other' 'Hybrid' 'Diesel']

# %%
print(len(df["fuelType"].unique()))
# Out:
# 4

# %%
print(len(df["transmission"].unique()))
# Out:
# 4

# %% [markdown]
# #### Find the relation between the numerical variables
#
# - Scatterplot of mileage vs price
# - Scatterplot of mpg vs price
# - Scatterplot of engineSize vs price

# %%
plt.figure(figsize=(20,16))

plt.subplot(3, 1, 1)
sns.scatterplot(x="mileage", y="price", data=df)

plt.subplot(3, 1, 2)
sns.scatterplot(x="mpg", y="price", data=df)

plt.subplot(3, 1, 3)
sns.scatterplot(x="engineSize", y="price", data=df)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Changing the hue parameter

# %%
plt.figure(figsize=(20,16))

plt.subplot(2, 2, 1)
sns.scatterplot(x="mileage", y="price", data=df, hue="fuelType")

plt.subplot(2, 2, 2)
sns.scatterplot(x="mpg", y="price", data=df, hue="fuelType")

plt.subplot(2, 2, 3)
sns.scatterplot(x="engineSize", y="price", data=df, hue="fuelType")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Creating a **trend line**

# %%
plt.figure(figsize=(20,16))

plt.subplot(2, 2, 1)
sns.regplot(x="mileage", y="price", data=df)

plt.subplot(2, 2, 2)
sns.regplot(x="mileage", y="price", data=df,line_kws={"color":"red"})

plt.subplot(2, 2, 3)
sns.regplot(x="mileage", y="price", data=df, scatter_kws={"color":"orange", "edgecolor":"white"})

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Pairplot

# %% [markdown]
# #### Checking an example from the documentation(Time saving)

# %%
penguins = sns.load_dataset("penguins")

display(penguins.head())
print(penguins.shape)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# (344, 7)

# %%
sns.pairplot(penguins)
plt.show()

# %%
sns.pairplot(penguins, hue="species")
plt.show()

# %%
sns.pairplot(df) 
plt.show()

# %% [markdown]
# #### Removing the additional plots

# %%
sns.pairplot(df, corner=True)    # to remove redundant information corner=True

# %% [markdown]
# #### Adding categorical feature

# %%
sns.pairplot(df, corner=True, hue="transmission")

# %% [markdown]
# #### References:
# [1] Seaborn Scatterplot: https://seaborn.pydata.org/generated/seaborn.scatterplot.html
# <br>[2] Seaborn Regression Line: https://seaborn.pydata.org/generated/seaborn.regplot.html
# <br>[3] Seaborn Pairplot: https://seaborn.pydata.org/generated/seaborn.pairplot.html#seaborn.pairplot
# <br>[4]dataset source: https://www.kaggle.com/aishwaryamuthukumar/cars-dataset-audi-bmw-ford-hyundai-skoda-vw
